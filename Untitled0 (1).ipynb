# %%
# !pip install dhanhq
# Out:
# Collecting dhanhq
#   Downloading dhanhq-2.2.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pandas>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from dhanhq) (2.2.2)
# Requirement already satisfied: requests>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from dhanhq) (2.32.4)
# Requirement already satisfied: websockets>=12.0.1 in /usr/local/lib/python3.12/dist-packages (from dhanhq) (15.0.1)
# Requirement already satisfied: pyOpenSSL>=20.0.1 in /usr/local/lib/python3.12/dist-packages (from dhanhq) (24.2.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.3->dhanhq) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.3->dhanhq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.3->dhanhq) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.3->dhanhq) (2026.1)
# Requirement already satisfied: cryptography<44,>=41.0.5 in /usr/local/lib/python3.12/dist-packages (from pyOpenSSL>=20.0.1->dhanhq) (43.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.1->dhanhq) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.1->dhanhq) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.1->dhanhq) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.1->dhanhq) (2026.4.22)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<44,>=41.0.5->pyOpenSSL>=20.0.1->dhanhq) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.3->dhanhq) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<44,>=41.0.5->pyOpenSSL>=20.0.1->dhanhq) (3.0)
# Downloading dhanhq-2.2.0-py3-none-any.whl (36 kB)
# Installing collected packages: dhanhq
# Successfully installed dhanhq-2.2.0

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from scipy.signal import argrelextrema

class SRBacktester:
    def __init__(self, ticker="^NSEI", order=5):
        self.ticker = ticker
        self.order = order

    def get_signals(self, interval='5m', period='1mo'):
        df = yf.download(self.ticker, period=period, interval=interval)
        if df.empty: return pd.DataFrame()

        # Find all peaks and troughs in one go
        df['Support_Pts'] = df.iloc[argrelextrema(df.Low.values, np.less, order=self.order)[0]]['Low']
        df['Resist_Pts'] = df.iloc[argrelextrema(df.High.values, np.greater, order=self.order)[0]]['High']

        df['Signal'] = 0  # 1 for Buy, -1 for Sell

        # We start from where we have at least 2 points for S and R
        # This is a simplified loop for backtesting logic
        for i in range(len(df)):
            if i < self.order*4: continue

            # Look at data available up to 'i' (to avoid look-ahead bias)
            lookback = df.iloc[:i]
            s_series = lookback['Support_Pts'].dropna()
            r_series = lookback['Resist_Pts'].dropna()

            if len(s_series) >= 2 and len(r_series) >= 2:
                # Support Ray projection
                s_p1_idx, s_p1_val = s_series.index[-2], s_series.iloc[-2].item()
                s_p2_idx, s_p2_val = s_series.index[-1], s_series.iloc[-1].item()

                # Math: slope = (y2-y1)/(x2-x1)
                m_s = (s_p2_val - s_p1_val) / (s_p2_idx.value - s_p1_idx.value)
                proj_s = s_p2_val + m_s * (df.index[i].value - s_p2_idx.value)

                # Resistance Ray projection
                r_p1_idx, r_p1_val = r_series.index[-2], r_series.iloc[-2].item()
                r_p2_idx, r_p2_val = r_series.index[-1], r_series.iloc[-1].item()

                m_r = (r_p2_val - r_p1_val) / (r_p2_idx.value - r_p1_idx.value)
                proj_r = r_p2_val + m_r * (df.index[i].value - r_p2_idx.value)

                # Check crossover
                res_current_close = df['Low'].iloc[i].item()
                sup_current_close = df['High'].iloc[i].item()

                if res_current_close > proj_r:
                    df.iloc[i, df.columns.get_loc('Signal')] = 1
                elif sup_current_close < proj_s:
                    df.iloc[i, df.columns.get_loc('Signal')] = -1

        return df

# Run and Analyze
tester = SRBacktester()
results = tester.get_signals(interval='15m', period='1mo') # Changed period to '1mo' to satisfy 60-day limit for 15m interval
print(results)
# Simple Performance Metric
#results['Returns'] = results['Close'].pct_change()
#results['Strategy_Returns'] = results['Signal'].shift(1) * results['Returns']
#print(f"Cumulative Strategy Return: {(1 + results['Strategy_Returns']).prod() - 1:.2%}")
# --- Realistic Performance Calculation ---

# 1. Define your costs (0.05% for slippage + taxes)
cost_per_trade = 0.0005

# 2. Identify where trades actually happened
# A trade occurs when the signal changes (e.g., from 0 to 1, or 1 to -1)
results['Trade_Signal'] = results['Signal'].diff().fillna(0)
results['Has_Traded'] = results['Trade_Signal'] != 0

# 3. Calculate Raw Strategy Returns
results['Returns'] = results['Close'].pct_change()
results['Strategy_Returns_Raw'] = results['Signal'].shift(1) * results['Returns']

# 4. Subtract Costs only on bars where a trade was executed
results['Strategy_Returns_Net'] = results['Strategy_Returns_Raw']
results.loc[results['Has_Traded'], 'Strategy_Returns_Net'] -= cost_per_trade

# 5. Compare Results
raw_final = (1 + results['Strategy_Returns_Raw']).prod() - 1
net_final = (1 + results['Strategy_Returns_Net']).prod() - 1
print(results['Has_Traded'].sum())
print(f"Raw Return: {raw_final:.2%}")
print(f"Net Return (After Costs): {net_final:.2%}")
# Out:
# /tmp/ipykernel_1942/1992947750.py:12: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period=period, interval=interval)
# [*********************100%***********************]  1 of 1 completed
# Price                             Close          High           Low  \
# Ticker                            ^NSEI         ^NSEI         ^NSEI
# Datetime
# 2026-03-30 03:45:00+00:00  22580.750000  22609.800781  22472.949219
# 2026-03-30 04:00:00+00:00  22659.250000  22713.300781  22576.750000
# 2026-03-30 04:15:00+00:00  22615.300781  22690.000000  22596.949219
# 2026-03-30 04:30:00+00:00  22596.750000  22665.500000  22556.599609
# 2026-03-30 04:45:00+00:00  22534.750000  22603.949219  22534.750000
# ...                                 ...           ...           ...
# 2026-04-29 05:45:00+00:00  24263.250000  24295.349609  24260.000000
# 2026-04-29 06:00:00+00:00  24271.849609  24286.400391  24263.500000
# 2026-04-29 06:15:00+00:00  24276.949219  24277.849609  24263.650391
# 2026-04-29 06:30:00+00:00  24293.150391  24311.150391  24267.550781
# 2026-04-29 06:45:00+00:00  24312.349609  24316.150391  24293.199219
#
# Price                              Open Volume Support_Pts    Resist_Pts  \
# Ticker                            ^NSEI  ^NSEI
# Datetime
# 2026-03-30 03:45:00+00:00  22574.699219      0         NaN           NaN
# 2026-03-30 04:00:00+00:00  22581.400391      0         NaN  22713.300781
# 2026-03-30 04:15:00+00:00  22659.550781      0         NaN           NaN
# 2026-03-30 04:30:00+00:00  22614.699219      0         NaN           NaN
# 2026-03-30 04:45:00+00:00  22595.900391      0         NaN           NaN
# ...                                 ...    ...         ...           ...
# 2026-04-29 05:45:00+00:00  24289.900391      0         NaN           NaN
# 2026-04-29 06:00:00+00:00  24266.099609      0         NaN           NaN
# 2026-04-29 06:15:00+00:00  24273.300781      0         NaN           NaN
# 2026-04-29 06:30:00+00:00  24278.199219      0         NaN           NaN
# 2026-04-29 06:45:00+00:00  24295.099609      0         NaN           NaN
#
# Price                     Signal
# Ticker
# Datetime
# 2026-03-30 03:45:00+00:00      0
# 2026-03-30 04:00:00+00:00      0
# 2026-03-30 04:15:00+00:00      0
# 2026-03-30 04:30:00+00:00      0
# 2026-03-30 04:45:00+00:00      0
# ...                          ...
# 2026-04-29 05:45:00+00:00      1
# 2026-04-29 06:00:00+00:00      1
# 2026-04-29 06:15:00+00:00      1
# 2026-04-29 06:30:00+00:00      1
# 2026-04-29 06:45:00+00:00      1
#
# [465 rows x 8 columns]
# 38
# Raw Return: 9.57%
# Net Return (After Costs): 7.51%

# %%
from dhanhq import dhanhq
import pandas as pd
import numpy as np

# Configuration
client_id = "YOUR_CLIENT_ID"
access_token = "YOUR_ACCESS_TOKEN"
dhan = dhanhq(client_id, access_token)

def get_atm_strike(spot_price):
    """Returns the nearest Nifty strike price."""
    return round(spot_price / 50) * 50

def place_paper_order(signal, spot_price):
    """
    Simulates an order. In a real live scenario, you'd fetch the
    Security ID for the specific strike from Dhan's Option Chain.
    """
    strike = get_atm_strike(spot_price)
    option_type = "CALL" if signal == 1 else "PUT"

    print(f"--- [PAPER TRADE EXECUTED] ---")
    print(f"Signal: {option_type} | Nifty Spot: {spot_price} | Strike: {strike}")
    # To actually place a real trade, you'd use:
    # dhan.place_order(tag='SR_Strategy', transaction_type=dhan.BUY, ...)

# --- Integration Example ---
# 1. Fetch Live OHLC for Nifty (Security ID for Nifty 50 Index is '13')
data = dhan.get_historical_data(
    symbol='NIFTY',
    exchange_segment='IDX_I',
    instrument_type='INDEX',
    expiry_code=0,
    from_date='2026-04-18', # Adjust to current date
    to_date='2026-04-20',
    interval='15'
)

# 2. Convert to DataFrame and apply your SRBacktesterIST logic here
# ... (Use the logic from the previous response) ...

# 3. Check latest Signal
# if latest_signal == 1:
#    place_paper_order(1, current_spot)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from scipy.signal import argrelextrema
import time
from datetime import datetime
import pytz

class LivePaperTrader:
    def __init__(self, ticker="^NSEI", order=10, interval='1m', target_pct=0.01, stoploss_pct=0.005):
        self.ticker = ticker
        self.order = order
        self.interval = interval
        self.position = 0  # 1 for Long, -1 for Short, 0 for Flat
        self.entry_price = 0.0
        self.trade_log = "paper_trade_log.csv"
        self.ist = pytz.timezone('Asia/Kolkata')

        # Risk Management Parameters
        self.target_pct = target_pct
        self.stoploss_pct = stoploss_pct

        print(f"--- Live Paper Trader Started ---")
        print(f"Ticker: {self.ticker} | Target: {target_pct*100}% | SL: {stoploss_pct*100}%")

    def get_latest_signal(self):
        df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
        if df.empty: return None, None

        if df.index.tz is None:
            df.index = df.index.tz_localize('UTC').tz_convert(self.ist)
        else:
            df.index = df.index.tz_convert(self.ist)

        df['Support_Pts'] = df.iloc[argrelextrema(df.Low.values, np.less, order=self.order)[0]]['Low']
        df['Resist_Pts'] = df.iloc[argrelextrema(df.High.values, np.greater, order=self.order)[0]]['High']

        s_series = df['Support_Pts'].dropna()
        r_series = df['Resist_Pts'].dropna()

        if len(s_series) < 2 or len(r_series) < 2:
            return 0, df.iloc[-1]['Close'].item()

        last_idx = -1
        current_close = df['Close'].iloc[last_idx].item()
        current_high = df['High'].iloc[last_idx].item()
        current_low = df['Low'].iloc[last_idx].item()
        current_time = df.index[last_idx]

        # Support/Resistance Projection Logic
        s_p1_idx, s_p1_val = s_series.index[-2], s_series.iloc[-2].item()
        s_p2_idx, s_p2_val = s_series.index[-1], s_series.iloc[-1].item()
        m_s = (s_p2_val - s_p1_val) / (s_p2_idx.value - s_p1_idx.value)
        proj_s = s_p2_val + m_s * (current_time.value - s_p2_idx.value)
        print("support:",s_p1_idx,s_p1_val,s_p2_idx,s_p2_val,proj_s)


        r_p1_idx, r_p1_val = r_series.index[-2], r_series.iloc[-2].item()
        r_p2_idx, r_p2_val = r_series.index[-1], r_series.iloc[-1].item()
        m_r = (r_p2_val - r_p1_val) / (r_p2_idx.value - r_p1_idx.value)
        proj_r = r_p2_val + m_r * (current_time.value - r_p2_idx.value)
        print("resistance:",r_p1_idx,r_p1_val,r_p2_idx,r_p2_val,proj_r)
        signal = 0
        if current_low > proj_r:
            signal = 1  # Bullish Breakout
        elif current_high < proj_s:
            signal = -1 # Bearish Breakout

        return signal, current_close

    def log_trade(self, action, price, reason="Signal"):
        timestamp = datetime.now(self.ist).strftime("%Y-%m-%d %H:%M:%S")
        log_entry = pd.DataFrame([{
            "Timestamp": timestamp,
            "Action": action,
            "Price": round(price, 2),
            "Ticker": self.ticker,
            "Reason": reason
        }])
        log_entry.to_csv(self.trade_log, mode='a', header=not pd.io.common.file_exists(self.trade_log), index=False)
        print(f"[{timestamp}] {action} at {price:.2f} ({reason})")

    def run(self):
        while True:
            try:
                signal, price = self.get_latest_signal()
                if signal is None:
                    continue

                # --- EXIT LOGIC (SL / Target) ---
                if self.position == 1: # Long
                    if price >= self.entry_price * (1 + self.target_pct):
                        self.log_trade("EXIT/LONG", price, "TARGET HIT")
                        self.position = 0
                    elif price <= self.entry_price * (1 - self.stoploss_pct):
                        self.log_trade("EXIT/LONG", price, "STOP LOSS HIT")
                        self.position = 0

                elif self.position == -1: # Short
                    if price <= self.entry_price * (1 - self.target_pct):
                        self.log_trade("EXIT/SHORT", price, "TARGET HIT")
                        self.position = 0
                    elif price >= self.entry_price * (1 + self.stoploss_pct):
                        self.log_trade("EXIT/SHORT", price, "STOP LOSS HIT")
                        self.position = 0
                else:
                    print(f"Holding Position: {self.position} | Current Price: {price:.2f}")

                # --- ENTRY LOGIC (Signals) ---
                if self.position == 0:
                    if signal == 1:
                        self.log_trade("BUY/LONG", price, "Breakout")
                        self.position = 1
                        self.entry_price = price
                    elif signal == -1:
                        self.log_trade("SELL/SHORT", price, "Breakout")
                        self.position = -1
                        self.entry_price = price

                # Console Update
                status = "FLAT" if self.position == 0 else ("LONG" if self.position == 1 else "SHORT")
                print(f"[{datetime.now(self.ist).strftime('%H:%M:%S')}] Price: {price:.2f} | Pos: {status}", end='\r')

                time.sleep(30)

            except Exception as e:
                print(f"\nError: {e}")
                time.sleep(10)

if __name__ == "__main__":
    # Example: 0.5% Target, 0.25% Stop Loss
    bot = LivePaperTrader(ticker="^NSEI", interval='1m', target_pct=0.000025, stoploss_pct=0.000015)
    bot.run()
# Out:
# --- Live Paper Trader Started ---
# Ticker: ^NSEI | Target: 0.0025% | SL: 0.0015%
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:17:00+05:30 24311.650390625 24311.7041015625
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24338.39921875
# Holding Position: 0 | Current Price: 24313.05
# [13:22:16] Price: 24313.05 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:17:00+05:30 24311.650390625 24311.7041015625
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24338.39921875
# Holding Position: 0 | Current Price: 24314.30
# [13:22:46] Price: 24314.30 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:22:00+05:30 24310.849609375 24310.815378289473
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24338.69921875
# Holding Position: 0 | Current Price: 24314.30
# [13:23:17] Price: 24314.30 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:22:00+05:30 24310.849609375 24310.815378289473
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24338.69921875
# Holding Position: 0 | Current Price: 24314.75
# [13:23:47] Price: 24314.75 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:22:00+05:30 24310.849609375 24310.781147203947
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24338.99921875
# Holding Position: 0 | Current Price: 24312.80
# [13:24:17] Price: 24312.80 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24308.2966796875
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24338.99921875
# Holding Position: 0 | Current Price: 24308.15
# [2026-04-29 13:24:47] SELL/SHORT at 24308.15 (Breakout)
# [13:24:47] Price: 24308.15 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24306.0
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24339.29921875
# [2026-04-29 13:25:17] EXIT/SHORT at 24311.75 (STOP LOSS HIT)
# [13:25:17] Price: 24311.75 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24306.0
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24339.29921875
# Holding Position: 0 | Current Price: 24313.15
# [13:25:48] Price: 24313.15 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24305.75
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24339.59921875
# Holding Position: 0 | Current Price: 24312.30
# [13:26:18] Price: 24312.30 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24305.75
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24339.59921875
# Holding Position: 0 | Current Price: 24316.65
# [13:26:48] Price: 24316.65 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24305.5
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24339.89921875
# Holding Position: 0 | Current Price: 24313.90
# [13:27:18] Price: 24313.90 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24305.5
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24339.89921875
# Holding Position: 0 | Current Price: 24310.85
# [13:27:48] Price: 24310.85 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24305.25
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24340.19921875
# Holding Position: 0 | Current Price: 24311.45
# [13:28:19] Price: 24311.45 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24305.25
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24340.19921875
# Holding Position: 0 | Current Price: 24310.80
# [13:28:49] Price: 24310.80 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24305.0
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24340.49921875
# Holding Position: 0 | Current Price: 24309.55
# [13:29:19] Price: 24309.55 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:24:00+05:30 24306.25 24305.0
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24340.49921875
# Holding Position: 0 | Current Price: 24307.10
# [13:29:49] Price: 24307.10 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24304.334209735578
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24340.79921875
# Holding Position: 0 | Current Price: 24311.25
# [13:30:20] Price: 24311.25 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24304.334209735578
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24340.79921875
# Holding Position: 0 | Current Price: 24311.95
# [13:30:50] Price: 24311.95 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24304.068810096152
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24341.09921875
# Holding Position: 0 | Current Price: 24312.20
# [13:31:20] Price: 24312.20 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24304.068810096152
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24341.09921875
# Holding Position: 0 | Current Price: 24313.80
# [13:31:51] Price: 24313.80 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24303.80341045673
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24341.39921875
# Holding Position: 0 | Current Price: 24314.65
# [13:32:21] Price: 24314.65 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24303.80341045673
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24341.39921875
# Holding Position: 0 | Current Price: 24311.10
# [13:32:51] Price: 24311.10 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24303.53801081731
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24341.69921875
# Holding Position: 0 | Current Price: 24313.00
# [13:33:21] Price: 24313.00 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24303.53801081731
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24341.69921875
# Holding Position: 0 | Current Price: 24314.60
# [13:33:51] Price: 24314.60 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24303.272611177883
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24341.99921875
# Holding Position: 0 | Current Price: 24311.85
# [13:34:22] Price: 24311.85 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24303.272611177883
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24341.99921875
# Holding Position: 0 | Current Price: 24313.20
# [13:34:52] Price: 24313.20 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24303.00721153846
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24342.29921875
# Holding Position: 0 | Current Price: 24315.45
# [13:35:22] Price: 24315.45 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:29:00+05:30 24304.599609375 24303.00721153846
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24342.29921875
# Holding Position: 0 | Current Price: 24308.90
# [13:35:52] Price: 24308.90 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24306.4662109375
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24342.59921875
# Holding Position: 0 | Current Price: 24299.70
# [2026-04-29 13:36:23] SELL/SHORT at 24299.70 (Breakout)
# [13:36:23] Price: 24299.70 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24306.4662109375
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24342.59921875
# [2026-04-29 13:36:53] EXIT/SHORT at 24300.80 (STOP LOSS HIT)
# [2026-04-29 13:36:53] SELL/SHORT at 24300.80 (Breakout)
# [13:36:53] Price: 24300.80 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:36:00+05:30 24296.69921875 24296.250710227272
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24342.89921875
# [13:37:23] Price: 24300.90 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:36:00+05:30 24296.69921875 24296.250710227272
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24342.89921875
# [2026-04-29 13:37:53] EXIT/SHORT at 24298.55 (TARGET HIT)
# [13:37:53] Price: 24298.55 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:36:00+05:30 24296.69921875 24296.250710227272
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24342.89921875
# Holding Position: 0 | Current Price: 24297.85
# [13:38:24] Price: 24297.85 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24306.1611328125
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24343.19921875
# Holding Position: 0 | Current Price: 24289.20
# [2026-04-29 13:38:54] SELL/SHORT at 24289.20 (Breakout)
# [13:38:54] Price: 24289.20 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:38:00+05:30 24285.05078125 24284.295089285715
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24343.49921875
# [13:39:24] Price: 24289.05 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24306.00859375
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24343.49921875
# [2026-04-29 13:39:54] EXIT/SHORT at 24283.45 (TARGET HIT)
# [2026-04-29 13:39:54] SELL/SHORT at 24283.45 (Breakout)
# [13:39:54] Price: 24283.45 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24305.8560546875
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24343.79921875
# [2026-04-29 13:40:24] EXIT/SHORT at 24277.35 (TARGET HIT)
# [2026-04-29 13:40:24] SELL/SHORT at 24277.35 (Breakout)
# [13:40:24] Price: 24277.35 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24305.8560546875
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24343.79921875
# [13:40:55] Price: 24277.15 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24305.703515625
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24344.09921875
# [2026-04-29 13:41:25] EXIT/SHORT at 24275.30 (TARGET HIT)
# [2026-04-29 13:41:25] SELL/SHORT at 24275.30 (Breakout)
# [13:41:25] Price: 24275.30 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:40:00+05:30 24275.30078125 24274.322423986487
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24344.09921875
# [2026-04-29 13:41:55] EXIT/SHORT at 24276.10 (STOP LOSS HIT)
# [13:41:55] Price: 24276.10 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24305.5509765625
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24344.39921875
# Holding Position: 0 | Current Price: 24268.60
# [2026-04-29 13:42:25] SELL/SHORT at 24268.60 (Breakout)
# [13:42:25] Price: 24268.60 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:41:00+05:30 24273.19921875 24272.191303453947
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24344.39921875
# [2026-04-29 13:42:56] EXIT/SHORT at 24280.55 (STOP LOSS HIT)
# [13:42:56] Price: 24280.55 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:42:00+05:30 24267.5 24266.371794871793
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24344.69921875
# Holding Position: 0 | Current Price: 24278.00
# [13:43:26] Price: 24278.00 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:42:00+05:30 24267.5 24266.371794871793
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24344.69921875
# Holding Position: 0 | Current Price: 24276.90
# [13:43:56] Price: 24276.90 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:42:00+05:30 24267.5 24265.24358974359
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24344.99921875
# Holding Position: 0 | Current Price: 24275.75
# [13:44:26] Price: 24275.75 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:42:00+05:30 24267.5 24266.371794871793
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24344.69921875
# Holding Position: 0 | Current Price: 24275.40
# [13:44:57] Price: 24275.40 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:42:00+05:30 24267.5 24264.115384615383
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24345.29921875
# Holding Position: 0 | Current Price: 24272.65
# [13:45:27] Price: 24272.65 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24305.093359375
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24345.29921875
# Holding Position: 0 | Current Price: 24267.25
# [2026-04-29 13:45:57] SELL/SHORT at 24267.25 (Breakout)
# [13:45:57] Price: 24267.25 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24304.9408203125
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24345.59921875
# [2026-04-29 13:46:27] EXIT/SHORT at 24265.65 (TARGET HIT)
# [2026-04-29 13:46:27] SELL/SHORT at 24265.65 (Breakout)
# [13:46:27] Price: 24265.65 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:45:00+05:30 24266.0 24264.916666666668
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24345.59921875
# [2026-04-29 13:46:58] EXIT/SHORT at 24268.15 (STOP LOSS HIT)
# [13:46:58] Price: 24268.15 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:46:00+05:30 24262.150390625 24261.0027252907
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24345.89921875
# Holding Position: 0 | Current Price: 24269.45
# [13:47:28] Price: 24269.45 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:46:00+05:30 24262.150390625 24261.0027252907
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24345.89921875
# Holding Position: 0 | Current Price: 24264.10
# [13:47:58] Price: 24264.10 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 12:43:00+05:30 24314.55078125 2026-04-29 13:03:00+05:30 24311.5 24304.6357421875
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24346.19921875
# Holding Position: 0 | Current Price: 24257.60
# [2026-04-29 13:48:28] SELL/SHORT at 24257.60 (Breakout)
# [13:48:28] Price: 24257.60 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:46:00+05:30 24262.150390625 24261.0027252907
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24345.89921875
# [2026-04-29 13:48:59] EXIT/SHORT at 24264.05 (STOP LOSS HIT)
# [13:48:59] Price: 24264.05 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24254.35737847222
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24346.49921875
# Holding Position: 0 | Current Price: 24265.60
# [13:49:29] Price: 24265.60 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24254.35737847222
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24346.49921875
# Holding Position: 0 | Current Price: 24267.05
# [13:49:59] Price: 24267.05 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24253.115147569446
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24346.79921875
# Holding Position: 0 | Current Price: 24269.45
# [13:50:29] Price: 24269.45 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24253.115147569446
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24346.79921875
# Holding Position: 0 | Current Price: 24271.35
# [13:51:00] Price: 24271.35 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24251.872916666667
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24347.09921875
# Holding Position: 0 | Current Price: 24263.40
# [13:51:30] Price: 24263.40 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24251.872916666667
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24347.09921875
# Holding Position: 0 | Current Price: 24269.00
# [13:52:00] Price: 24269.00 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24250.63068576389
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24347.39921875
# Holding Position: 0 | Current Price: 24272.95
# [13:52:30] Price: 24272.95 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24250.63068576389
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24347.39921875
# Holding Position: 0 | Current Price: 24277.20
# [13:53:00] Price: 24277.20 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24249.38845486111
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24347.69921875
# Holding Position: 0 | Current Price: 24281.10
# [13:53:31] Price: 24281.10 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24249.38845486111
# resistance: 2026-04-29 12:53:00+05:30 24329.69921875 2026-04-29 13:08:00+05:30 24334.19921875 24347.69921875
# Holding Position: 0 | Current Price: 24278.10
# [13:54:01] Price: 24278.10 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24248.146223958334
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24282.16970486111
# Holding Position: 0 | Current Price: 24273.90
# [13:54:31] Price: 24273.90 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24248.146223958334
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24282.16970486111
# Holding Position: 0 | Current Price: 24269.85
# [13:55:01] Price: 24269.85 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24248.146223958334
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24282.16970486111
# Holding Position: 0 | Current Price: 24269.85
# [13:55:31] Price: 24269.85 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24245.661762152777
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24279.907552083332
# Holding Position: 0 | Current Price: 24278.50
# [13:56:02] Price: 24278.50 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24245.661762152777
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24279.907552083332
# Holding Position: 0 | Current Price: 24272.15
# [13:56:32] Price: 24272.15 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24244.41953125
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24278.776475694445
# Holding Position: 0 | Current Price: 24272.90
# [13:57:02] Price: 24272.90 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24244.41953125
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24278.776475694445
# Holding Position: 0 | Current Price: 24267.50
# [13:57:32] Price: 24267.50 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24244.41953125
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24278.776475694445
# Holding Position: 0 | Current Price: 24261.70
# [13:58:02] Price: 24261.70 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24243.177300347223
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24277.645399305555
# Holding Position: 0 | Current Price: 24264.05
# [13:58:33] Price: 24264.05 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24241.935069444444
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24276.514322916668
# Holding Position: 0 | Current Price: 24267.40
# [13:59:03] Price: 24267.40 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24241.935069444444
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24276.514322916668
# Holding Position: 0 | Current Price: 24262.95
# [13:59:33] Price: 24262.95 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24240.692838541665
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24275.383246527777
# Holding Position: 0 | Current Price: 24254.90
# [14:00:03] Price: 24254.90 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24240.692838541665
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24275.383246527777
# Holding Position: 0 | Current Price: 24254.30
# [14:00:34] Price: 24254.30 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:00:00+05:30 24246.650390625 24245.904622395832
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24274.25217013889
# Holding Position: 0 | Current Price: 24258.05
# [14:01:04] Price: 24258.05 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:00:00+05:30 24246.650390625 24245.904622395832
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24274.25217013889
# Holding Position: 0 | Current Price: 24258.25
# [14:01:34] Price: 24258.25 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:00:00+05:30 24246.650390625 24245.158854166668
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24273.12109375
# Holding Position: 0 | Current Price: 24254.35
# [14:02:04] Price: 24254.35 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24238.20837673611
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24273.12109375
# Holding Position: 0 | Current Price: 24245.20
# [14:02:34] Price: 24245.20 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:02:00+05:30 24245.19921875 24244.45633370536
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24271.99001736111
# Holding Position: 0 | Current Price: 24247.50
# [14:03:05] Price: 24247.50 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24236.966145833332
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24271.99001736111
# Holding Position: 0 | Current Price: 24238.75
# [14:03:35] Price: 24238.75 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24235.723914930557
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24270.858940972223
# Holding Position: 0 | Current Price: 24205.25
# [2026-04-29 14:04:05] SELL/SHORT at 24205.25 (Breakout)
# [14:04:05] Price: 24205.25 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24235.723914930557
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24270.858940972223
# [2026-04-29 14:04:35] EXIT/SHORT at 24205.95 (STOP LOSS HIT)
# [2026-04-29 14:04:35] SELL/SHORT at 24205.95 (Breakout)
# [14:04:35] Price: 24205.95 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:03:00+05:30 24311.5 2026-04-29 13:48:00+05:30 24255.599609375 24235.723914930557
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24270.858940972223
# [2026-04-29 14:05:05] EXIT/SHORT at 24202.45 (TARGET HIT)
# [2026-04-29 14:05:05] SELL/SHORT at 24202.45 (Breakout)
# [14:05:05] Price: 24202.45 | Pos: SHORT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24197.321899414062
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24269.727864583332
# [2026-04-29 14:05:36] EXIT/SHORT at 24208.25 (STOP LOSS HIT)
# [14:05:36] Price: 24208.25 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24193.893798828125
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24268.596788194445
# Holding Position: 0 | Current Price: 24206.10
# [14:06:06] Price: 24206.10 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24193.893798828125
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24268.596788194445
# Holding Position: 0 | Current Price: 24208.50
# [14:06:36] Price: 24208.50 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24190.465698242188
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24267.465711805555
# Holding Position: 0 | Current Price: 24218.45
# [14:07:06] Price: 24218.45 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24190.465698242188
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24267.465711805555
# Holding Position: 0 | Current Price: 24224.45
# [14:07:36] Price: 24224.45 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24187.03759765625
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24266.334635416668
# Holding Position: 0 | Current Price: 24218.80
# [14:08:07] Price: 24218.80 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24187.03759765625
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24266.334635416668
# Holding Position: 0 | Current Price: 24215.75
# [14:08:37] Price: 24215.75 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24183.609497070312
# resistance: 2026-04-29 13:08:00+05:30 24334.19921875 2026-04-29 13:53:00+05:30 24283.30078125 24265.203559027777
# Holding Position: 0 | Current Price: 24213.35
# [14:09:07] Price: 24213.35 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:04:00+05:30 24200.75 24183.609497070312
# ...
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24169.849609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24189.906123991936
# [2026-04-29 14:37:20] EXIT/LONG at 24197.70 (STOP LOSS HIT)
# [2026-04-29 14:37:20] BUY/LONG at 24197.70 (Breakout)
# [14:37:20] Price: 24197.70 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24169.849609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24189.906123991936
# [2026-04-29 14:37:50] EXIT/LONG at 24196.55 (STOP LOSS HIT)
# [2026-04-29 14:37:50] BUY/LONG at 24196.55 (Breakout)
# [14:37:50] Price: 24196.55 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24168.099609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24187.783518145163
# [2026-04-29 14:38:20] EXIT/LONG at 24200.65 (TARGET HIT)
# [2026-04-29 14:38:20] BUY/LONG at 24200.65 (Breakout)
# [14:38:20] Price: 24200.65 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24168.099609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24187.783518145163
# [2026-04-29 14:38:51] EXIT/LONG at 24199.70 (STOP LOSS HIT)
# [2026-04-29 14:38:51] BUY/LONG at 24199.70 (Breakout)
# [14:38:51] Price: 24199.70 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24166.349609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24185.660912298386
# [2026-04-29 14:39:21] EXIT/LONG at 24200.60 (TARGET HIT)
# [2026-04-29 14:39:21] BUY/LONG at 24200.60 (Breakout)
# [14:39:21] Price: 24200.60 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24166.349609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24185.660912298386
# [2026-04-29 14:39:51] EXIT/LONG at 24203.35 (TARGET HIT)
# [2026-04-29 14:39:51] BUY/LONG at 24203.35 (Breakout)
# [14:39:51] Price: 24203.35 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24164.599609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24183.538306451614
# [2026-04-29 14:40:21] EXIT/LONG at 24207.90 (TARGET HIT)
# [2026-04-29 14:40:21] BUY/LONG at 24207.90 (Breakout)
# [14:40:21] Price: 24207.90 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24164.599609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24183.538306451614
# [2026-04-29 14:40:51] EXIT/LONG at 24212.10 (TARGET HIT)
# [2026-04-29 14:40:51] BUY/LONG at 24212.10 (Breakout)
# [14:40:51] Price: 24212.10 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24162.849609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24181.415700604837
# [2026-04-29 14:41:22] EXIT/LONG at 24214.80 (TARGET HIT)
# [2026-04-29 14:41:22] BUY/LONG at 24214.80 (Breakout)
# [14:41:22] Price: 24214.80 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24162.849609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24181.415700604837
# [2026-04-29 14:41:52] EXIT/LONG at 24217.25 (TARGET HIT)
# [2026-04-29 14:41:52] BUY/LONG at 24217.25 (Breakout)
# [14:41:52] Price: 24217.25 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24161.099609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:41:00+05:30 24218.19921875 24218.240349264706
# [2026-04-29 14:42:22] EXIT/LONG at 24215.95 (STOP LOSS HIT)
# [14:42:22] Price: 24215.95 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24161.099609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24179.293094758064
# Holding Position: 0 | Current Price: 24222.00
# [2026-04-29 14:42:53] BUY/LONG at 24222.00 (Breakout)
# [14:42:53] Price: 24222.00 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24159.349609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:42:00+05:30 24224.0 24224.36111111111
# [2026-04-29 14:43:23] EXIT/LONG at 24220.35 (STOP LOSS HIT)
# [14:43:23] Price: 24220.35 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24161.099609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24179.293094758064
# Holding Position: 0 | Current Price: 24223.45
# [2026-04-29 14:43:53] BUY/LONG at 24223.45 (Breakout)
# [14:43:53] Price: 24223.45 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24159.349609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24177.17048891129
# [2026-04-29 14:44:24] EXIT/LONG at 24217.65 (STOP LOSS HIT)
# [2026-04-29 14:44:24] BUY/LONG at 24217.65 (Breakout)
# [14:44:24] Price: 24217.65 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24157.599609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24175.047883064515
# [2026-04-29 14:44:54] EXIT/LONG at 24228.40 (TARGET HIT)
# [2026-04-29 14:44:54] BUY/LONG at 24228.40 (Breakout)
# [14:44:54] Price: 24228.40 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24155.849609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:44:00+05:30 24229.25 24229.8375
# [2026-04-29 14:45:24] EXIT/LONG at 24226.60 (STOP LOSS HIT)
# [14:45:24] Price: 24226.60 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24155.849609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:44:00+05:30 24229.25 24229.8375
# Holding Position: 0 | Current Price: 24222.90
# [14:45:54] Price: 24222.90 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24155.849609375
# resistance: 2026-04-29 13:53:00+05:30 24283.30078125 2026-04-29 14:24:00+05:30 24217.5 24172.925277217742
# Holding Position: 0 | Current Price: 24222.95
# [2026-04-29 14:46:24] BUY/LONG at 24222.95 (Breakout)
# [14:46:24] Price: 24222.95 | Pos: LONG
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24154.099609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24231.32775297619
# [2026-04-29 14:46:55] EXIT/LONG at 24201.85 (STOP LOSS HIT)
# [14:46:55] Price: 24201.85 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24152.349609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24231.95628720238
# Holding Position: 0 | Current Price: 24205.05
# [14:47:25] Price: 24205.05 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24154.099609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24231.32775297619
# Holding Position: 0 | Current Price: 24202.80
# [14:47:55] Price: 24202.80 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24152.349609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24231.95628720238
# Holding Position: 0 | Current Price: 24202.75
# [14:48:25] Price: 24202.75 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24150.599609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24232.584821428572
# Holding Position: 0 | Current Price: 24208.25
# [14:48:56] Price: 24208.25 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24148.849609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24233.213355654763
# Holding Position: 0 | Current Price: 24205.15
# [14:49:26] Price: 24205.15 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24148.849609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24233.213355654763
# Holding Position: 0 | Current Price: 24205.00
# [14:49:56] Price: 24205.00 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24147.099609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24233.841889880954
# Holding Position: 0 | Current Price: 24202.25
# [14:50:26] Price: 24202.25 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 13:48:00+05:30 24255.599609375 2026-04-29 14:30:00+05:30 24182.099609375 24148.849609375
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24233.213355654763
# Holding Position: 0 | Current Price: 24206.00
# [14:50:56] Price: 24206.00 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 14:30:00+05:30 24182.099609375 2026-04-29 14:50:00+05:30 24197.0 24197.74501953125
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24234.47042410714
# Holding Position: 0 | Current Price: 24201.55
# [14:51:27] Price: 24201.55 | Pos: FLAT
# /tmp/ipykernel_1942/4286400435.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(self.ticker, period='7d', interval=self.interval, progress=False)
# support: 2026-04-29 14:30:00+05:30 24182.099609375 2026-04-29 14:50:00+05:30 24197.0 24197.74501953125
# resistance: 2026-04-29 14:24:00+05:30 24217.5 2026-04-29 14:45:00+05:30 24230.69921875 24234.47042410714
# Holding Position: 0 | Current Price: 24200.35
# [14:51:57] Price: 24200.35 | Pos: FLAT
